# %%
# built in data type
# creating a set
s1 = {1, 2, 3, 4, 5}
print(type(s1))
# Out:
# <class 'set'>

# %%
# emtpy set
s2 = {}
print(type(s2))
# Out:
# <class 'dict'>

# %%
s3 = {
    1,
    "a",
    "b",
    "c",
    3,
    4,
}

print(s3)
# Out:
# {1, 3, 'c', 4, 'b', 'a'}

# %%
s3 = {1, 1, "a", "b", 3, 5, "d", "d"}
print(s3)
# Out:
# {1, 3, 'd', 5, 'b', 'a'}

# %%
# operation on set
# add and removing element

s3.add(8)
print(s3)
# Out:
# {1, 3, 'd', 5, 8, 'b', 'a'}

# %%
s3.remove(3)

# %%
s3
# Out:
# {1, 5, 8, 'a', 'b', 'd'}

# %%
s3.remove("sakshi")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s3.remove("sakshi")
#
# KeyError: 'sakshi'

# %%
s3
# Out:
# {1, 5, 8, 'a', 'b', 'd'}

# %%
s3.discard(11)

# %%
s3.pop()
print(s3)
# Out:
# {5, 8, 'b', 'a'}

# %%
# clear all the element
s3.clear()

# %%
# Set membership opersatro
s3 = {1, 2, 3, 4, 4, 5, 6, 7, 8}
print(3 in s3)
# Out:
# True

# %%
# mathematical operation
s2 = {12, 3, 4, 5}

# union
union_set = s3.union(s2)
print(union_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 12}

# %%
# counting the unique word in the text
text = "In this tutorial we are discussing the about sets"
words = text.split()

# covert list of word to set to get unique word
unique_word = set(words)
print(unique_word)
print(len(unique_word))
# Out:
# {'the', 'In', 'tutorial', 'we', 'are', 'this', 'about', 'discussing', 'sets'}
# 9
