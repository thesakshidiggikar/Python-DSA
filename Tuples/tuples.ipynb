# %%
# tuples are immutable
#ordered collection of items

# %%
##creating tuple
emtpy_tuple = ()
print(type(emtpy_tuple))
# Out:
# <class 'tuple'>

# %%
tuple1 = (1, 2, 3, 4, 5, 5, 6, "A", "b", "c", "d", "e")
print(tuple)
# Out:
# <class 'tuple'>

# %%
tuple1
# Out:
# (1, 2, 3, 4, 5, 5, 6, 'A', 'b', 'c', 'd', 'e')

# %%
##accessign the tuple elements
tuple1[2]
# Out:
# 3

# %%
tuple1[2:7]
# Out:
# (3, 4, 5, 5, 6)

# %%
# imutable nature of tuple
lst = [1, 3, 4, 5]
tuplee = tuple([lst])
print(tuplee)
# Out:
# ([1, 3, 4, 5],)

# %%
##tuple methods

tuple1
# Out:
# (1, 2, 3, 4, 5, 5, 6, 'A', 'b', 'c', 'd', 'e')

# %%
# couunt
print(tuple1.count(1))
# Out:
# 1

# %%
print(tuple1.count(5))
# Out:
# 2

# %%
print(tuple1.index(5))
# Out:
# 4

# %%
# packing and unpacking
# packing
packed = "Hello", 3, 1.43
print(packed)
# Out:
# ('Hello', 3, 1.43)

# %%
# unpacking
a, b, c = packed
print(a)
# Out:
# Hello

# %%
print(b)
# Out:
# 3

# %%
print(c)
# Out:
# 1.43

# %%
# Unpacking with star
num = (1, 2, 3, 4, 5, 6, 77, 8)
f, *m, l = num
print(f)
# Out:
# 1

# %%
print(m)
# Out:
# [2, 3, 4, 5, 6, 77]

# %%
print(l)
# Out:
# 8

# %%
# nested tuple
lst = [[1, 2], [4, 5, [6]]]
lst[0]
# Out:
# [1, 2]
