# %%
# creating an array

import array

arr = array.array("i", [1, 2, 3, 4, 5])
print(arr)
print(type(arr))
# Out:
# array('i', [1, 2, 3, 4, 5])
# <class 'array.array'>

# %%
arr[4] = 6
arr
# Out:
# array('i', [1, 2, 3, 4, 6])
