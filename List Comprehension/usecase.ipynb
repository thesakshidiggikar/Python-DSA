# %%
# real -world example

# lst for keeping track of tasks

to_do_list = ["Buy grocessaey", "Clean the house", "Pay Bills", "Cook food"]

# add the task
to_do_list.append("Schedule Meeting")
to_do_list.append("Go to sleep soon")

# removing
to_do_list.remove("Cook food")

# checkig if a task is the list

if "Pay Bills" in to_do_list:
    print("Dont forget to pay the bills")

print("To do List remanining")

for task in to_do_list:
    print(f"-{task}")
# Out:
# Dont forget to pay the bills
# To do List remanining
# -Buy grocessaey
# -Clean the house
# -Pay Bills
# -Schedule Meeting
# -Go to sleep soon
